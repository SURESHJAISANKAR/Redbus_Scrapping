# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
from selenium.webdriver.support import expected_conditions as EC
import time
import re


driver = webdriver.Chrome()
driver.get("https://www.redbus.in/")
driver.maximize_window()
time.sleep(5)

wait = WebDriverWait(driver, 10)
try:
     state_bus = wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR,"a[href='https://www.redbus.in/online-booking/rtc-directory']")))
     actions = ActionChains(driver)
     actions.move_to_element(state_bus).perform()
     print("Successfully Moved")
     time.sleep(2)
     state_bus.click()

except Exception as e:
    print("Class Not Located",e)

driver.switch_to.window(driver.window_handles[1])

try:
    bus_available = wait.until(EC.element_to_be_clickable((By.XPATH, "//a[@class='D113_link' and text()='APSRTC']")))
    actions = ActionChains(driver)
    actions.move_to_element(bus_available).perform()
    print("Successfully Moved")
    time.sleep(2)
    bus_available.click()
    time.sleep(2)
    bus_details = wait.until(EC.element_to_be_clickable((By.CLASS_NAME, "route"))).click()
    # bus_details.click()
    time.sleep(10)
    gvt_bus = wait.until(EC.presence_of_all_elements_located((By.XPATH, "//div[@class='button' and text()='View Buses']")))
    for button in reversed(gvt_bus):
        button.click()
    
except Exception as e:
    print("data not Scrapped")

try:
    bulk_list = []
    busname=[]
    bustype = []
    departing_time = []
    duration = []
    reaching_time = []
    star_rating = []
    price = []
    seats_available = []
    last_height = driver.execute_script("return document.body.scrollHeight")
    print(last_height)
    scrolling = True
    while scrolling:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        time.sleep(3)

        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

    bus_name_details = wait.until(EC.presence_of_all_elements_located((By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")))
    # bustype_details = wait.until(EC.presence_of_all_elements_located((By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")))
    bustype_details = wait.until(EC.presence_of_all_elements_located((By.CSS_SELECTOR, ".bus-type.f-12.m-top-16.l-color.evBus")))
    departing_time_details = wait.until(EC.presence_of_all_elements_located((By.CSS_SELECTOR, ".dp-time.f-19.d-color.f-bold")))
    reaching_time_details = wait.until(EC.presence_of_all_elements_located((By.CSS_SELECTOR, ".bp-time.f-19.d-color.disp-Inline")))
    duration_details = wait.until(EC.presence_of_all_elements_located((By.XPATH, "//div[@class='dur l-color lh-24']")))
    star_rating_details = wait.until(EC.presence_of_all_elements_located((By.CSS_SELECTOR, "div.rating-sec.lh-24")))
    price_details = wait.until(EC.presence_of_all_elements_located((By.CSS_SELECTOR, "div.seat-fare")))
    seats_available_details = wait.until(EC.presence_of_all_elements_located((By.CSS_SELECTOR, "div.column-eight.w-15.fl")))

    for i in bus_name_details:
        busname.append(i.text)

    for i in bustype_details:
        bustype.append(i.text)
    
    for i in departing_time_details:
        departing_time.append(i.text)

    for i in reaching_time_details:
        reaching_time.append(i.text)

    for i in duration_details:
        duration.append(i.text)    

    for i in star_rating_details:
        star_rating.append(i.text)

    for i in price_details:
        price.append(i.text)

    for i in seats_available_details:
        seats_available.append(i.text)    

except Exception as e:
    print(f"An ERROR Occured : {e}")


seats = [int(i.split()[0]) for i in seats_available]
final_price = [int(re.findall(r'\d+',i)[0]) for i in price]

# bulk_list.append(bus_)
bulk_list.append(busname)
bulk_list.append(bustype)
bulk_list.append(departing_time)
bulk_list.append(reaching_time)
bulk_list.append(duration)
bulk_list.append(star_rating)
bulk_list.append(final_price)
bulk_list.append(seats)

for i in bulk_list:
    print(type(i))
print(bulk_list, type(bulk_list))
# Out:
# Successfully Moved
# Successfully Moved
# 11071
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 120
#     118 bulk_list.append(star_rating)
#     119 bulk_list.append(final_price)
# --> 120 bulk_list.append(int(seats))
#     122 for i in bulk_list:
#     123     print(type(i))
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 
# ['3.4', '3.7', '4.7', '2.6', '3.4', '3.9', '4.4', '3.5', '3.0', '3.0', '4.4', '3.6', '4.0', '4.1', '3.4', '2.7', '3.7', '3.8', '4.2', '3.9', '4.1', '3.5', '3.5', '3.9', '3.9', '3.9', '4.0', '3.0', '3.7', '4.8', '4.1', '4.6', '4.7', '4.5', '3.8', '4.2', '4.1', '3.8', '3.6', '4.2', '4.7', '3.6', '4.2', '4.3', '2.6', '4.3', '4.3', '4.2', '4.4', '4.5', '4.6', '3.1', '3.5', '3.8', '4.5', '4.3', '4.7', '4.6', '3.5', '4.7', '4.7', '4.6', '4.5', '4.5', '4.5', '4.6', '4.5', '4.3', '4.4', '4.3', '4.2', '4.3', '4.3', '4.2', '4.1', '4.5', '4.1', '4.0', '4.6', '4.3', '4.2', '4.1', '4.0', '4.2', '4.4', '4.2', '4.0', '4.2', '4.6', '4.3', '4.2', '3.4', '3.1', '3.2', '3.9', '3.9', '3.8', '3.8', '3.8', '3.9', '3.4', '3.4', '3.9', '3.4', '3.3', '3.5', '3.5', '3.2', '3.1', '3.8', '3.7', '3.6', '3.6', '3.5', '2.8', '2.4', '1.3', '1.5', '2.6', '1.9', '1.5', '2.8', '2.6', '2.7', '2.6', '2.6', '2.7', '2.0']
# [533, 396, 396, 480, 542, 396, 533, 396, 396, 480, 396, 533, 561, 442, 480, 480, 396, 396, 536, 396, 533, 480, 533, 396, 396, 440, 533, 480, 396, 469, 469, 781, 469, 469, 469, 720, 720, 781, 567, 720, 469, 839, 607, 469, 567, 781, 567, 436, 720, 720, 720, 567, 781, 839, 567, 899, 811, 880, 999, 749, 811, 1036, 880, 700, 792, 1176, 1134, 672, 1060, 655, 906, 1348, 1239, 950, 940, 889, 1060, 773, 1171, 1292, 800, 870, 870, 888, 849, 1111, 1090, 1100, 990, 770, 1000, 3000, 4000, 700, 799, 1060, 1222, 980, 1090, 1040, 800, 1200, 750, 1100, 1100, 710, 1099, 1360, 1200, 1333, 1880, 1400, 780, 940, 849, 1300, 799, 1100, 799, 3000, 1100, 3999, 4000, 1100, 860, 999, 1299, 999, 1200, 1090]
# ['36 Seats available\n16 Window', '30 Seats available', '27 Seats available', '23 Seats available\n8 Window', '11 Seats available', '26 Seats available', '20 Seats available\n9 Window', '29 Seats available', '19 Seats available', '37 Seats available\n18 Window', '24 Seats available', '12 Seats available\n2 Window', '11 Seats available\n3 Single', '12 Seats available\n2 Single', '11 Seats available\n5 Window', '9 Seats available\n4 Window', '2 Seats available', '22 Seats available', '7 Seats available\n1 Window', '6 Seats available', '8 Seats available\n2 Window', '26 Seats available\n13 Window', '18 Seats available\n8 Window', '7 Seats available', '6 Seats available', '31 Seats available', '3 Seats available\n1 Window', '29 Seats available\n13 Window', '19 Seats available', '1 Seat available', '3 Seats available', '11 Seats available\n1 Single', '1 Seat available', '1 Seat available', '2 Seats available', '1 Seat available', '6 Seats available\n2 Window', '11 Seats available\n6 Window', '5 Seats available', '5 Seats available\n2 Window', '2 Seats available', '1 Seat available', '1 Seat available', '1 Seat available', '1 Seat available', '9 Seats available\n2 Single', '2 Seats available', '3 Seats available', '1 Seat available', '2 Seats available', '3 Seats available', '2 Seats available', '11 Seats available\n1 Single', '2 Seats available\n1 Window', '1 Seat available', '12 Seats available\n4 Window', '4 Seats available\n2 Single', '7 Seats available', '15 Seats available\n6 Window', '2 Seats available\n1 Window', '8 Seats available\n3 Single', '1 Seat available', '6 Seats available\n1 Window', '7 Seats available\n3 Window', '10 Seats available\n2 Single', '7 Seats available', '6 Seats available\n5 Window', '1 Seat available', '3 Seats available\n1 Window', '4 Seats available', '1 Seat available', '2 Seats available\n1 Window', '10 Seats available\n1 Single', '1 Seat available', '1 Seat available\n1 Single', '6 Seats available\n1 Window', '3 Seats available', '2 Seats available', '6 Seats available\n1 Single', '6 Seats available\n2 Single', '3 Seats available', '1 Seat available', '1 Seat available', '1 Seat available', '5 Seats available\n1 Window', '2 Seats available', '3 Seats available\n1 Single', '8 Seats available', '2 Seats available', '1 Seat available', '5 Seats available', '40 Seats available\n10 Single', '32 Seats available', '13 Seats available\n5 Window', '1 Seat available', '2 Seats available', '2 Seats available\n1 Window', '1 Seat available', '2 Seats available', '1 Seat available', '4 Seats available\n2 Window', '3 Seats available\n1 Window', '1 Seat available', '6 Seats available\n3 Window', '8 Seats available\n4 Window', '1 Seat available', '5 Seats available\n1 Window', '2 Seats available\n1 Window', '2 Seats available\n1 Window', '3 Seats available', '1 Seat available\n1 Window', '1 Seat available', '1 Seat available', '4 Seats available\n1 Window', '25 Seats available\n3 Single', '16 Seats available\n5 Single', '11 Seats available\n6 Window', '16 Seats available\n1 Single', '25 Seats available\n11 Window', '35 Seats available\n17 Window', '13 Seats available\n2 Single', '44 Seats available', '40 Seats available', '7 Seats available\n3 Window', '2 Seats available\n1 Single', '1 Seat available', '1 Seat available', '2 Seats available', '4 Seats available\n2 Window', '3 Seats available\n1 Single']

# %%
import pandas as pd
header = ['Bus Name', 'Bus Type', 'Departure Time', 'Arrival Time','Duration','Star Rating','Price','Seats Available']
# header = ['Bus Name', 'Bus Type', 'Departure Time', 'Arrival Time','Duration']
df=pd.DataFrame(bulk_list,header)
df = df.T
df.insert(0,'Id',range(1,len(df)+1))
# print(df)
# print(df.head())  # Check the first few rows
# print(df.columns)
df.to_csv('route.csv',index=False)
df.info()
df['Star Rating'].fillna(0.0, inplace=True)
df.info()

# %%
from sqlalchemy import create_engine, text, MetaData, Table, Column, Integer, String, Float, Time
engine = create_engine('mysql+pymysql://root:root@localhost')
with engine.connect() as connection:
    connection.execute(text('CREATE DATABASE IF NOT EXISTS RedbusInfo'))
engine = create_engine('mysql+pymysql://root:root@localhost/RedbusInfo')

# %%
drop_table_sql = 'DROP TABLE IF EXISTS bus_info;'
with engine.connect() as connection:
    connection.execute(text(drop_table_sql))

# %%
create_table_sql = '''
CREATE TABLE IF NOT EXISTS bus_info (
    Id INT,
    `Bus Name` VARCHAR(255),
    `Bus Type` VARCHAR(255),
    `Departure Time` VARCHAR(50),
    `Arrival Time` VARCHAR(50),
    `Star Rating` FLOAT,
    `Duration` VARCHAR(50),
    `Price` INT,
    `Seats Available` INT
) ROW_FORMAT=DYNAMIC;
'''
# Execute the table creation SQL
with engine.connect() as connection:
    connection.execute(text(create_table_sql))

# Insert the data into the pre-created table
df.to_sql('bus_info', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# File d:\vscode\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1936, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1935     if not evt_handled:
# -> 1936         self.dialect.do_executemany(
#    1937             cursor,
#    1938             str_statement,
#    1939             effective_parameters,
#    1940             context,
#    1941         )
#    1942 elif not effective_parameters and context.no_parameters:
#
# File d:\vscode\.venv\Lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:170, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     169 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 170     rowcount = cursor.executemany(statement, parameters)
#     171     if context is not None:
#
# File d:\vscode\.venv\Lib\site-packages\pymysql\cursors.py:182, in Cursor.executemany(self, query, args)
#     181     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 182     return self._do_execute_many(
#     183         q_prefix,
#     184         q_values,
#     185         q_postfix,
#     186         args,
#     187         self.max_stmt_length,
#     188         self._get_db().encoding,
#     189     )
#     191 self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# File d:\vscode\.venv\Lib\site-packages\pymysql\cursors.py:220, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     219     sql += v
# --> 220 rows += self.execute(sql + postfix)
#     221 self.rowcount = rows
#
# File d:\vscode\.venv\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#
# File d:\vscode\.venv\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#
# File d:\vscode\.venv\Lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File d:\vscode\.venv\Lib\site-packages\pymysql\connections.py:825, in Connection._read_query_result(self, unbuffered)
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#
# File d:\vscode\.venv\Lib\site-packages\pymysql\connections.py:1199, in MySQLResult.read(self)
#    1198 try:
# -> 1199     first_packet = self.connection._read_packet()
#    1201     if first_packet.is_ok_packet():
#
# File d:\vscode\.venv\Lib\site-packages\pymysql\connections.py:775, in Connection._read_packet(self, packet_type)
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File d:\vscode\.venv\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File d:\vscode\.venv\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# DataError: (1265, "Data truncated for column 'Seats Available' at row 1")
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# Cell In[17], line 19
#      16     connection.execute(text(create_table_sql))
#      18 # Insert the data into the pre-created table
# ---> 19 df.to_sql('bus_info', con=engine, if_exists='append', index=False)
#
# File d:\vscode\.venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File d:\vscode\.venv\Lib\site-packages\pandas\core\generic.py:3087, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2889 """
#    2890 Write records stored in a DataFrame to a SQL database.
#    2891
#    (...)
#    3083 [(1,), (None,), (2,)]
#    3084 """  # noqa: E501
#    3085 from pandas.io import sql
# -> 3087 return sql.to_sql(
#    3088     self,
#    3089     name,
#    3090     con,
#    3091     schema=schema,
#    3092     if_exists=if_exists,
#    3093     index=index,
#    3094     index_label=index_label,
#    3095     chunksize=chunksize,
#    3096     dtype=dtype,
#    3097     method=method,
#    3098 )
#
# File d:\vscode\.venv\Lib\site-packages\pandas\io\sql.py:842, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     837     raise NotImplementedError(
#     838         "'frame' argument should be either a Series or a DataFrame"
#     839     )
#     841 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 842     return pandas_sql.to_sql(
#     843         frame,
#     844         name,
#     845         if_exists=if_exists,
#     846         index=index,
#     847         index_label=index_label,
#     848         schema=schema,
#     849         chunksize=chunksize,
#     850         dtype=dtype,
#     851         method=method,
#     852         engine=engine,
#     853         **engine_kwargs,
#     854     )
#
# File d:\vscode\.venv\Lib\site-packages\pandas\io\sql.py:2018, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2006 sql_engine = get_engine(engine)
#    2008 table = self.prep_table(
#    2009     frame=frame,
#    2010     name=name,
#    (...)
#    2015     dtype=dtype,
#    2016 )
# -> 2018 total_inserted = sql_engine.insert_records(
#    2019     table=table,
#    2020     con=self.con,
#    2021     frame=frame,
#    2022     name=name,
#    2023     index=index,
#    2024     schema=schema,
#    2025     chunksize=chunksize,
#    2026     method=method,
#    2027     **engine_kwargs,
#    2028 )
#    2030 self.check_case_sensitive(name=name, schema=schema)
#    2031 return total_inserted
#
# File d:\vscode\.venv\Lib\site-packages\pandas\io\sql.py:1567, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1565 if re.search(msg, err_text):
#    1566     raise ValueError("inf cannot be used with MySQL") from err
# -> 1567 raise err
#
# File d:\vscode\.venv\Lib\site-packages\pandas\io\sql.py:1558, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1555 from sqlalchemy import exc
#    1557 try:
# -> 1558     return table.insert(chunksize=chunksize, method=method)
#    1559 except exc.StatementError as err:
#    1560     # GH34431
#    1561     # https://stackoverflow.com/a/67358288/6067848
#    1562     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1563     )|inf can not be used with MySQL"""
#
# File d:\vscode\.venv\Lib\site-packages\pandas\io\sql.py:1119, in SQLTable.insert(self, chunksize, method)
#    1116     break
#    1118 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1119 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1120 # GH 46891
#    1121 if num_inserted is not None:
#
# File d:\vscode\.venv\Lib\site-packages\pandas\io\sql.py:1010, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     998 """
#     999 Execute SQL statement inserting data
#    1000
#    (...)
#    1007    Each item contains a list of values to be inserted
#    1008 """
#    1009 data = [dict(zip(keys, row)) for row in data_iter]
# -> 1010 result = conn.execute(self.table.insert(), data)
#    1011 return result.rowcount
#
# File d:\vscode\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1418, in Connection.execute(self, statement, parameters, execution_options)
#    1416     raise exc.ObjectNotExecutableError(statement) from err
#    1417 else:
# -> 1418     return meth(
#    1419         self,
#    1420         distilled_parameters,
#    1421         execution_options or NO_OPTIONS,
#    1422     )
#
# File d:\vscode\.venv\Lib\site-packages\sqlalchemy\sql\elements.py:515, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     513     if TYPE_CHECKING:
#     514         assert isinstance(self, Executable)
# --> 515     return connection._execute_clauseelement(
#     516         self, distilled_params, execution_options
#     517     )
#     518 else:
#     519     raise exc.ObjectNotExecutableError(self)
#
# File d:\vscode\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1640, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1628 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1629     "compiled_cache", self.engine._compiled_cache
#    1630 )
#    1632 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1633     dialect=dialect,
#    1634     compiled_cache=compiled_cache,
#    (...)
#    1638     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1639 )
# -> 1640 ret = self._execute_context(
#    1641     dialect,
#    1642     dialect.execution_ctx_cls._init_compiled,
#    1643     compiled_sql,
#    1644     distilled_parameters,
#    1645     execution_options,
#    1646     compiled_sql,
#    1647     distilled_parameters,
#    1648     elem,
#    1649     extracted_params,
#    1650     cache_hit=cache_hit,
#    1651 )
#    1652 if has_events:
#    1653     self.dispatch.after_execute(
#    1654         self,
#    1655         elem,
#    (...)
#    1659         ret,
#    1660     )
#
# File d:\vscode\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File d:\vscode\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File d:\vscode\.venv\Lib\site-packages\sqlalchemy\engine\base.py:2353, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2351 elif should_wrap:
#    2352     assert sqlalchemy_exception is not None
# -> 2353     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2354 else:
#    2355     assert exc_info[1] is not None
#
# File d:\vscode\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1936, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1934                 break
#    1935     if not evt_handled:
# -> 1936         self.dialect.do_executemany(
#    1937             cursor,
#    1938             str_statement,
#    1939             effective_parameters,
#    1940             context,
#    1941         )
#    1942 elif not effective_parameters and context.no_parameters:
#    1943     if self.dialect._has_events:
#
# File d:\vscode\.venv\Lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:170, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     169 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 170     rowcount = cursor.executemany(statement, parameters)
#     171     if context is not None:
#     172         context._rowcount = rowcount
#
# File d:\vscode\.venv\Lib\site-packages\pymysql\cursors.py:182, in Cursor.executemany(self, query, args)
#     180     q_postfix = m.group(3) or ""
#     181     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 182     return self._do_execute_many(
#     183         q_prefix,
#     184         q_values,
#     185         q_postfix,
#     186         args,
#     187         self.max_stmt_length,
#     188         self._get_db().encoding,
#     189     )
#     191 self.rowcount = sum(self.execute(query, arg) for arg in args)
#     192 return self.rowcount
#
# File d:\vscode\.venv\Lib\site-packages\pymysql\cursors.py:220, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     218         sql += b","
#     219     sql += v
# --> 220 rows += self.execute(sql + postfix)
#     221 self.rowcount = rows
#     222 return rows
#
# File d:\vscode\.venv\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File d:\vscode\.venv\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File d:\vscode\.venv\Lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#     561     sql = sql.encode(self.encoding, "surrogateescape")
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File d:\vscode\.venv\Lib\site-packages\pymysql\connections.py:825, in Connection._read_query_result(self, unbuffered)
#     823 else:
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#     827 if result.server_status is not None:
#
# File d:\vscode\.venv\Lib\site-packages\pymysql\connections.py:1199, in MySQLResult.read(self)
#    1197 def read(self):
#    1198     try:
# -> 1199         first_packet = self.connection._read_packet()
#    1201         if first_packet.is_ok_packet():
#    1202             self._read_ok_packet(first_packet)
#
# File d:\vscode\.venv\Lib\site-packages\pymysql\connections.py:775, in Connection._read_packet(self, packet_type)
#     773     if self._result is not None and self._result.unbuffered_active is True:
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File d:\vscode\.venv\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File d:\vscode\.venv\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# DataError: (pymysql.err.DataError) (1265, "Data truncated for column 'Seats Available' at row 1")
# [SQL: INSERT INTO bus_info (`Id`, `Bus Name`, `Bus Type`, `Departure Time`, `Arrival Time`, `Duration`, `Star Rating`, `Price`, `Seats Available`) VALUES (%(Id)s, %(Bus_Name)s, %(Bus_Type)s, %(Departure_Time)s, %(Arrival_Time)s, %(Duration)s, %(Star_Rating)s, %(Price)s, %(Seats_Available)s)]
# [parameters: [{'Id': 1, 'Bus_Name': 'TSRTC - 41931', 'Bus_Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departure_Time': '04:10', 'Arrival_Time': '09:10', 'Duration': '05h 00m', 'Star_Rating': '4.6', 'Price': 396, 'Seats_Available': '11 Seats available'}, {'Id': 2, 'Bus_Name': 'TSRTC - 1132', 'Bus_Type': 'RAJDHANI (A.C. Semi Sleeper)', 'Departure_Time': '05:30', 'Arrival_Time': '11:20', 'Duration': '05h 50m', 'Star_Rating': '2.9', 'Price': 533, 'Seats_Available': '9 Seats available\n1 Window'}, {'Id': 3, 'Bus_Name': 'TSRTC - 40577', 'Bus_Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departure_Time': '06:30', 'Arrival_Time': '11:20', 'Duration': '04h 50m', 'Star_Rating': '3.7', 'Price': 396, 'Seats_Available': '10 Seats available'}, {'Id': 4, 'Bus_Name': 'TSRTC - 1959', 'Bus_Type': 'RAJDHANI (A.C. Semi Sleeper)', 'Departure_Time': '06:50', 'Arrival_Time': '12:50', 'Duration': '06h 00m', 'Star_Rating': '3.9', 'Price': 533, 'Seats_Available': '23 Seats available\n9 Window'}, {'Id': 5, 'Bus_Name': 'TSRTC - 2981', 'Bus_Type': 'RAJADHANI AC (CONVERTED METRO LUXURY)', 'Departure_Time': '07:20', 'Arrival_Time': '13:00', 'Duration': '05h 40m', 'Star_Rating': '1.7', 'Price': 480, 'Seats_Available': '21 Seats available\n7 Window'}, {'Id': 6, 'Bus_Name': 'TSRTC - 1596', 'Bus_Type': 'RAJDHANI (A.C. Semi Sleeper)', 'Departure_Time': '07:40', 'Arrival_Time': '12:15', 'Duration': '04h 35m', 'Star_Rating': '1.9', 'Price': 533, 'Seats_Available': '33 Seats available\n16 Window'}, {'Id': 7, 'Bus_Name': 'TSRTC - 7693', 'Bus_Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departure_Time': '08:00', 'Arrival_Time': '13:20', 'Duration': '05h 20m', 'Star_Rating': '4.0', 'Price': 396, 'Seats_Available': '13 Seats available'}, {'Id': 8, 'Bus_Name': 'TSRTC - 31110', 'Bus_Type': 'RAJDHANI (A.C. Semi Sleeper)', 'Departure_Time': '08:40', 'Arrival_Time': '14:20', 'Duration': '05h 40m', 'Star_Rating': '3.2', 'Price': 480, 'Seats_Available': '23 Seats available\n7 Window'}  ... displaying 10 of 386 total bound parameter sets ...  {'Id': 385, 'Bus_Name': 'Sri Krishna Travels', 'Bus_Type': 'Volvo Multi-Axle A/C Sleeper (2+1)', 'Departure_Time': '23:35', 'Arrival_Time': '06:45', 'Duration': '07h 10m', 'Star_Rating': 0.0, 'Price': 1200, 'Seats_Available': '29 Seats available\n8 Single'}, {'Id': 386, 'Bus_Name': 'Naveen Tours and Travels', 'Bus_Type': 'A/C Seater/Sleeper (2+1)', 'Departure_Time': '23:30', 'Arrival_Time': '05:30', 'Duration': '06h 00m', 'Star_Rating': 0.0, 'Price': 3999, 'Seats_Available': '44 Seats available'}]]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
